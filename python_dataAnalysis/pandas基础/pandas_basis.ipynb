# %% [markdown]
# * # Pandas 基础
# 1. 如何理解dataframe的基本要素
# 2. DataFrame的数据结构
# 3. 什么是series,针对Series的链式方法
# 4. 对DataFrame的列名，行名，索引进行修改

# %% [markdown]
# * ### 什么是DataFrame

# %% [markdown]
#  Pandas中有两种基础数据结构，Series和DataFrame.Series是一种类似于一维数组的对象，由一组数据和一组与之相关的数据标签（即索引）组成。

# %% [markdown]
#  DataFrame既有行索引，又有列索引，可以看做是由Series组成的字典。

# %%
# 导入Pandas包
import pandas as pd
# 设置Notebook中最多显示多少行，超出部分用省略号代替
pd.set_option('display.max_colwidth',20)
pd.set_option('display.max_rows',8)
# 记录数据所在根目录
data_source = r"Y:\BaiduNetdiskWorkspace\data_analysis\Python数据分析\data"

# %%
retal_data = pd.read_csv(r'{}\Online_Retail_Fake.csv'.format(data_source))

# %%
retal_data[['InvoiceNo']]
# Out:
#        InvoiceNo
# 0         536365
# 1         536365
# 2         536365
# 3         536365
# ...          ...
# 541906    581587
# 541907    581587
# 541908    581587
# 541909    581587
#
# [541910 rows x 1 columns]

# %%
retal_data[1:3]
# Out:
#   InvoiceNo StockCode          Description  Quantity     InvoiceDate  \
# 1    536365     71053  WHITE METAL LANTERN         6  2010/12/1 8:26
# 2    536365    84406B                  NaN         8  2010/12/1 8:26
#
#    UnitPrice  CustomerID         Country
# 1        NaN     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom

# %%
retal_data.head()
# Out:
#   InvoiceNo StockCode          Description  Quantity     InvoiceDate  \
# 0    536365    85123A  WHITE HANGING HE...         6  2010/12/1 8:26
# 1    536365     71053  WHITE METAL LANTERN         6  2010/12/1 8:26
# 2    536365    84406B                  NaN         8  2010/12/1 8:26
# 3    536365    84029G  KNITTED UNION FL...         6  2010/12/1 8:26
# 4    536365    84029E  RED WOOLLY HOTTI...         6  2010/12/1 8:26
#
#    UnitPrice  CustomerID         Country
# 0       2.55     17850.0  United Kingdom
# 1        NaN     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom
# 3       3.39     17850.0  United Kingdom
# 4       3.39     17850.0  United Kingdom

# %% [markdown]
# ## 一个DataFrame有一个数轴（Index）和一个横轴（Cloumns），pandas借用了NumPy的命名方式，0/1分别表示竖轴/横轴。即称（Index）为DataFrame的0轴指的是函数作用于行。

# %%
index = retal_data.index
colunms = retal_data.columns
data = retal_data.values

# %%
index
# Out:
# RangeIndex(start=0, stop=541910, step=1)

# %%
colunms
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
data
# Out:
# array([['536365', '85123A', 'WHITE HANGING HEART T-LIGHT HOLDER', ...,
#         2.55, 17850.0, 'United Kingdom'],
#        ['536365', '71053', 'WHITE METAL LANTERN', ..., nan, 17850.0,
#         'United Kingdom'],
#        ['536365', '84406B', nan, ..., 2.75, 17850.0, 'United Kingdom'],
#        ...,
#        ['581587', '23255', 'CHILDRENS CUTLERY CIRCUS PARADE', ..., 4.15,
#         12680.0, 'France'],
#        ['581587', '22138', 'BAKING SET 9 PIECE RETROSPOT ', ..., 4.95,
#         12680.0, 'France'],
#        ['581587', '22138', 'Wrong booking', ..., 4.95, 12680.0, 'France']],
#       dtype=object)

# %%
index_value = index.values
index_value
# Out:
# array([     0,      1,      2, ..., 541907, 541908, 541909], dtype=int64)

# %%
cv = colunms.values
cv
# Out:
# array(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'], dtype=object)

# %%
data
# Out:
# array([['536365', '85123A', 'WHITE HANGING HEART T-LIGHT HOLDER', ...,
#         2.55, 17850.0, 'United Kingdom'],
#        ['536365', '71053', 'WHITE METAL LANTERN', ..., nan, 17850.0,
#         'United Kingdom'],
#        ['536365', '84406B', nan, ..., 2.75, 17850.0, 'United Kingdom'],
#        ...,
#        ['581587', '23255', 'CHILDRENS CUTLERY CIRCUS PARADE', ..., 4.15,
#         12680.0, 'France'],
#        ['581587', '22138', 'BAKING SET 9 PIECE RETROSPOT ', ..., 4.95,
#         12680.0, 'France'],
#        ['581587', '22138', 'Wrong booking', ..., 4.95, 12680.0, 'France']],
#       dtype=object)

# %% [markdown]
# # ![pandas的数据类型](pandas的数据类型.jpg)

# %%
retal_data.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
# 获取列的大小
retal_data.columns.size
# Out:
# 8

# %%
## Series就是构成DataFrame的列，每一列就是一个Series。
## 比如访问Country列
ct = retal_data['Country']
ct
# Out:
# 0         United Kingdom
# 1         United Kingdom
# 2         United Kingdom
# 3         United Kingdom
#                ...
# 541906            France
# 541907            France
# 541908            France
# 541909            France
# Name: Country, Length: 541910, dtype: object

# %%
## 访问ct的name，length(实际是size)，dtype
print(ct.name,ct.size,ct.dtype,sep='---')
# Out:
# Country---541910---object

# %%
## 查看coutry的type
type(ct)
# Out:
# pandas.core.series.Series

# %%
## isnull()函数
ct.isnull().sum()
# Out:
# 1

# %%
ct.fillna(0).isnull().sum()
# Out:
# 0

# %% [markdown]
# * ## 修改索引与列名

# %%
gapminder = pd.read_csv(data_source+"/gapminder.csv")

# %%
gapminder.head()
# Out:
#    Unnamed: 0   1800   1801   1802   1803   1804   1805   1806   1807   1808  \
# 0           0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1           1  28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14  28.13
# 2           2    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3           3  35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4           4  28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#    ...  2008  2009  2010  2011  2012  2013  2014  2015  2016  \
# 0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#        Life expectancy
# 0             Abkhazia
# 1          Afghanistan
# 2  Akrotiri and Dhe...
# 3              Albania
# 4              Algeria
#
# [5 rows x 219 columns]

# %%
col = gapminder.columns
col.size
# Out:
# 219

# %%
col.values
# Out:
# array(['Unnamed: 0', '1800', '1801', '1802', '1803', '1804', '1805',
#        '1806', '1807', '1808', '1809', '1810', '1811', '1812', '1813',
#        '1814', '1815', '1816', '1817', '1818', '1819', '1820', '1821',
#        '1822', '1823', '1824', '1825', '1826', '1827', '1828', '1829',
#        '1830', '1831', '1832', '1833', '1834', '1835', '1836', '1837',
#        '1838', '1839', '1840', '1841', '1842', '1843', '1844', '1845',
#        '1846', '1847', '1848', '1849', '1850', '1851', '1852', '1853',
#        '1854', '1855', '1856', '1857', '1858', '1859', '1860', '1861',
#        '1862', '1863', '1864', '1865', '1866', '1867', '1868', '1869',
#        '1870', '1871', '1872', '1873', '1874', '1875', '1876', '1877',
#        '1878', '1879', '1880', '1881', '1882', '1883', '1884', '1885',
#        '1886', '1887', '1888', '1889', '1890', '1891', '1892', '1893',
#        '1894', '1895', '1896', '1897', '1898', '1899', '1900', '1901',
#        '1902', '1903', '1904', '1905', '1906', '1907', '1908', '1909',
#        '1910', '1911', '1912', '1913', '1914', '1915', '1916', '1917',
#        '1918', '1919', '1920', '1921', '1922', '1923', '1924', '1925',
#        '1926', '1927', '1928', '1929', '1930', '1931', '1932', '1933',
#        '1934', '1935', '1936', '1937', '1938', '1939', '1940', '1941',
#        '1942', '1943', '1944', '1945', '1946', '1947', '1948', '1949',
#        '1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957',
#        '1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', 'Life expectancy'], dtype=object)

# %%
gapminder = gapminder.set_index('Life expectancy')

# %%
gapminder
# Out:
#                       Unnamed: 0   1800  1801   1802   1803   1804   1805  \
# Life expectancy
# Abkhazia                       0    NaN   NaN    NaN    NaN    NaN    NaN
# Afghanistan                    1  28.21  28.2  28.19  28.18  28.17  28.16
# Akrotiri and Dhek...           2    NaN   NaN    NaN    NaN    NaN    NaN
# Albania                        3  35.40  35.4  35.40  35.40  35.40  35.40
# ...                          ...    ...   ...    ...    ...    ...    ...
# Zambia                       256    NaN   NaN    NaN    NaN    NaN    NaN
# Zimbabwe                     257    NaN   NaN    NaN    NaN    NaN    NaN
# Åland                        258    NaN   NaN    NaN    NaN    NaN    NaN
# South Sudan                  259    NaN   NaN    NaN    NaN    NaN    NaN
#
#                        1806   1807   1808  ...  2007  2008  2009  2010  2011  \
# Life expectancy                            ...
# Abkhazia                NaN    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN
# Afghanistan           28.15  28.14  28.13  ...   NaN   NaN   NaN   NaN   NaN
# Akrotiri and Dhek...    NaN    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN
# Albania               35.40  35.40  35.40  ...   NaN   NaN   NaN   NaN   NaN
# ...                     ...    ...    ...  ...   ...   ...   ...   ...   ...
# Zambia                  NaN    NaN    NaN  ...  49.0  51.1  52.3  53.1  53.7
# Zimbabwe                NaN    NaN    NaN  ...  46.4  47.3  48.0  49.1  51.6
# Åland                   NaN    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN
# South Sudan             NaN    NaN    NaN  ...  55.5  55.6  55.8  56.0  55.9
#
#                       2012  2013  2014  2015   2016
# Life expectancy
# Abkhazia               NaN   NaN   NaN   NaN    NaN
# Afghanistan            NaN   NaN   NaN   NaN    NaN
# Akrotiri and Dhek...   NaN   NaN   NaN   NaN    NaN
# Albania                NaN   NaN   NaN   NaN    NaN
# ...                    ...   ...   ...   ...    ...
# Zambia                54.7  55.6  56.3  56.7  57.10
# Zimbabwe              54.2  55.7  57.0  59.3  61.69
# Åland                  NaN   NaN   NaN   NaN    NaN
# South Sudan           56.0  56.0  56.1  56.1  56.10
#
# [780 rows x 218 columns]

# %%
gapminder = gapminder.reset_index('Life expectancy')

# %%
gapminder
# Out:
#          Life expectancy  Unnamed: 0   1800  1801   1802   1803   1804   1805  \
# 0               Abkhazia           0    NaN   NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan           1  28.21  28.2  28.19  28.18  28.17  28.16
# 2    Akrotiri and Dhe...           2    NaN   NaN    NaN    NaN    NaN    NaN
# 3                Albania           3  35.40  35.4  35.40  35.40  35.40  35.40
# ..                   ...         ...    ...   ...    ...    ...    ...    ...
# 776               Zambia         256    NaN   NaN    NaN    NaN    NaN    NaN
# 777             Zimbabwe         257    NaN   NaN    NaN    NaN    NaN    NaN
# 778                Åland         258    NaN   NaN    NaN    NaN    NaN    NaN
# 779          South Sudan         259    NaN   NaN    NaN    NaN    NaN    NaN
#
#       1806   1807  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0      NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    28.15  28.14  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    35.40  35.40  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..     ...    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 776    NaN    NaN  ...  49.0  51.1  52.3  53.1  53.7  54.7  55.6  56.3  56.7
# 777    NaN    NaN  ...  46.4  47.3  48.0  49.1  51.6  54.2  55.7  57.0  59.3
# 778    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 779    NaN    NaN  ...  55.5  55.6  55.8  56.0  55.9  56.0  56.0  56.1  56.1
#
#       2016
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# ..     ...
# 776  57.10
# 777  61.69
# 778    NaN
# 779  56.10
#
# [780 rows x 219 columns]

# %%
col_name= {
    'Life expectancy':'location','Unnamed: 0':'index'
}

## 用rename函数实现了列名的修改，当然也可以修改索引
gapminder = gapminder.rename(columns= col_name)
gapminder
# Out:
#                 location  index   1800  1801   1802   1803   1804   1805  \
# 0               Abkhazia      0    NaN   NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan      1  28.21  28.2  28.19  28.18  28.17  28.16
# 2    Akrotiri and Dhe...      2    NaN   NaN    NaN    NaN    NaN    NaN
# 3                Albania      3  35.40  35.4  35.40  35.40  35.40  35.40
# ..                   ...    ...    ...   ...    ...    ...    ...    ...
# 776               Zambia    256    NaN   NaN    NaN    NaN    NaN    NaN
# 777             Zimbabwe    257    NaN   NaN    NaN    NaN    NaN    NaN
# 778                Åland    258    NaN   NaN    NaN    NaN    NaN    NaN
# 779          South Sudan    259    NaN   NaN    NaN    NaN    NaN    NaN
#
#       1806   1807  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0      NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    28.15  28.14  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    35.40  35.40  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..     ...    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 776    NaN    NaN  ...  49.0  51.1  52.3  53.1  53.7  54.7  55.6  56.3  56.7
# 777    NaN    NaN  ...  46.4  47.3  48.0  49.1  51.6  54.2  55.7  57.0  59.3
# 778    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 779    NaN    NaN  ...  55.5  55.6  55.8  56.0  55.9  56.0  56.0  56.1  56.1
#
#       2016
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# ..     ...
# 776  57.10
# 777  61.69
# 778    NaN
# 779  56.10
#
# [780 rows x 219 columns]

# %%
## 另一方面，index和column也可以转换成list进行索引修改。
index = gapminder.index
colunms = gapminder.columns
index = index.to_list()
colunms = colunms.to_list()

colunms[0] = 'test'
## 可以通过给DataFrame类的文件赋值list类型的文件来修改colunms或者index
gapminder.columns = colunms
gapminder
# Out:
#                     test  index   1800  1801   1802   1803   1804   1805  \
# 0               Abkhazia      0    NaN   NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan      1  28.21  28.2  28.19  28.18  28.17  28.16
# 2    Akrotiri and Dhe...      2    NaN   NaN    NaN    NaN    NaN    NaN
# 3                Albania      3  35.40  35.4  35.40  35.40  35.40  35.40
# ..                   ...    ...    ...   ...    ...    ...    ...    ...
# 776               Zambia    256    NaN   NaN    NaN    NaN    NaN    NaN
# 777             Zimbabwe    257    NaN   NaN    NaN    NaN    NaN    NaN
# 778                Åland    258    NaN   NaN    NaN    NaN    NaN    NaN
# 779          South Sudan    259    NaN   NaN    NaN    NaN    NaN    NaN
#
#       1806   1807  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0      NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    28.15  28.14  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    35.40  35.40  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..     ...    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 776    NaN    NaN  ...  49.0  51.1  52.3  53.1  53.7  54.7  55.6  56.3  56.7
# 777    NaN    NaN  ...  46.4  47.3  48.0  49.1  51.6  54.2  55.7  57.0  59.3
# 778    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 779    NaN    NaN  ...  55.5  55.6  55.8  56.0  55.9  56.0  56.0  56.1  56.1
#
#       2016
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# ..     ...
# 776  57.10
# 777  61.69
# 778    NaN
# 779  56.10
#
# [780 rows x 219 columns]

# %% [markdown]
# * ## 添加、修改或者删除列

# %%
##　数据处理过程中有时需要进行列的添加修改和删除，我们先读入文件
retail_data = pd.read_csv(data_source+"\\Online_Retail_Fake.csv")

# %%
retail_data.head()
# Out:
#   InvoiceNo StockCode          Description  Quantity     InvoiceDate  \
# 0    536365    85123A  WHITE HANGING HE...         6  2010/12/1 8:26
# 1    536365     71053  WHITE METAL LANTERN         6  2010/12/1 8:26
# 2    536365    84406B                  NaN         8  2010/12/1 8:26
# 3    536365    84029G  KNITTED UNION FL...         6  2010/12/1 8:26
# 4    536365    84029E  RED WOOLLY HOTTI...         6  2010/12/1 8:26
#
#    UnitPrice  CustomerID         Country
# 0       2.55     17850.0  United Kingdom
# 1        NaN     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom
# 3       3.39     17850.0  United Kingdom
# 4       3.39     17850.0  United Kingdom

# %%
## 如表所示，表中有Quantity和UnitPrice，但是没有总价Total_price，我们添加一列Total_price
retail_data['Total_Price'] = retail_data['Quantity']*retail_data['UnitPrice']
retail_data[['Total_Price','Quantity','UnitPrice']]
# Out:
#         Total_Price  Quantity  UnitPrice
# 0             15.30         6       2.55
# 1               NaN         6        NaN
# 2             22.00         8       2.75
# 3             20.34         6       3.39
# ...             ...       ...        ...
# 541906        16.60         4       4.15
# 541907        16.60         4       4.15
# 541908        14.85         3       4.95
# 541909        14.85         3       4.95
#
# [541910 rows x 3 columns]

# %%
# 获取UnitPrice列的位置
UnitPrice_col_index = retail_data.columns.get_loc('UnitPrice')
# UnitPrice_col_index
# 使用insert()函数将Total_price列加入到指定位置
retail_data.insert(UnitPrice_col_index+1,'new_Total_Price',
                  value = retail_data['Total_Price'])

# %%
retail_data.head()
# Out:
#   InvoiceNo StockCode          Description  Quantity     InvoiceDate  \
# 0    536365    85123A  WHITE HANGING HE...         6  2010/12/1 8:26
# 1    536365     71053  WHITE METAL LANTERN         6  2010/12/1 8:26
# 2    536365    84406B                  NaN         8  2010/12/1 8:26
# 3    536365    84029G  KNITTED UNION FL...         6  2010/12/1 8:26
# 4    536365    84029E  RED WOOLLY HOTTI...         6  2010/12/1 8:26
#
#    UnitPrice  new_Total_Price  CustomerID         Country  Total_Price
# 0       2.55            15.30     17850.0  United Kingdom        15.30
# 1        NaN              NaN     17850.0  United Kingdom          NaN
# 2       2.75            22.00     17850.0  United Kingdom        22.00
# 3       3.39            20.34     17850.0  United Kingdom        20.34
# 4       3.39            20.34     17850.0  United Kingdom        20.34

# %%
# 删除列则需要drop（）函数
retail_data.drop('new_Total_Price',axis=1,inplace=True)

# %%
retail_data
# Out:
#        InvoiceNo StockCode          Description  Quantity      InvoiceDate  \
# 0         536365    85123A  WHITE HANGING HE...         6   2010/12/1 8:26
# 1         536365     71053  WHITE METAL LANTERN         6   2010/12/1 8:26
# 2         536365    84406B                  NaN         8   2010/12/1 8:26
# 3         536365    84029G  KNITTED UNION FL...         6   2010/12/1 8:26
# ...          ...       ...                  ...       ...              ...
# 541906    581587     23254  CHILDRENS CUTLER...         4  2011/12/9 12:50
# 541907    581587     23255  CHILDRENS CUTLER...         4  2011/12/9 12:50
# 541908    581587     22138  BAKING SET 9 PIE...         3  2011/12/9 12:50
# 541909    581587     22138        Wrong booking         3  2011/12/9 12:50
#
#         UnitPrice  CustomerID         Country  Total_Price
# 0            2.55     17850.0  United Kingdom        15.30
# 1             NaN     17850.0  United Kingdom          NaN
# 2            2.75     17850.0  United Kingdom        22.00
# 3            3.39     17850.0  United Kingdom        20.34
# ...           ...         ...             ...          ...
# 541906       4.15     12680.0          France        16.60
# 541907       4.15     12680.0          France        16.60
# 541908       4.95     12680.0          France        14.85
# 541909       4.95     12680.0          France        14.85
#
# [541910 rows x 9 columns]

# %%
## 除了用drop外，还可以用del来删除列
del retail_data['Total_Price']

# %%
retail_data
# Out:
#        InvoiceNo StockCode          Description  Quantity      InvoiceDate  \
# 0         536365    85123A  WHITE HANGING HE...         6   2010/12/1 8:26
# 1         536365     71053  WHITE METAL LANTERN         6   2010/12/1 8:26
# 2         536365    84406B                  NaN         8   2010/12/1 8:26
# 3         536365    84029G  KNITTED UNION FL...         6   2010/12/1 8:26
# ...          ...       ...                  ...       ...              ...
# 541906    581587     23254  CHILDRENS CUTLER...         4  2011/12/9 12:50
# 541907    581587     23255  CHILDRENS CUTLER...         4  2011/12/9 12:50
# 541908    581587     22138  BAKING SET 9 PIE...         3  2011/12/9 12:50
# 541909    581587     22138        Wrong booking         3  2011/12/9 12:50
#
#         UnitPrice  CustomerID         Country
# 0            2.55     17850.0  United Kingdom
# 1             NaN     17850.0  United Kingdom
# 2            2.75     17850.0  United Kingdom
# 3            3.39     17850.0  United Kingdom
# ...           ...         ...             ...
# 541906       4.15     12680.0          France
# 541907       4.15     12680.0          France
# 541908       4.95     12680.0          France
# 541909       4.95     12680.0          France
#
# [541910 rows x 8 columns]

# %%
# 除了常规数学运算，还可以对其进行逻辑运算
# 如：
retail_data['logic_test'] = retail_data['UnitPrice']>4
retail_data
# Out:
#        InvoiceNo StockCode          Description  Quantity      InvoiceDate  \
# 0         536365    85123A  WHITE HANGING HE...         6   2010/12/1 8:26
# 1         536365     71053  WHITE METAL LANTERN         6   2010/12/1 8:26
# 2         536365    84406B                  NaN         8   2010/12/1 8:26
# 3         536365    84029G  KNITTED UNION FL...         6   2010/12/1 8:26
# ...          ...       ...                  ...       ...              ...
# 541906    581587     23254  CHILDRENS CUTLER...         4  2011/12/9 12:50
# 541907    581587     23255  CHILDRENS CUTLER...         4  2011/12/9 12:50
# 541908    581587     22138  BAKING SET 9 PIE...         3  2011/12/9 12:50
# 541909    581587     22138        Wrong booking         3  2011/12/9 12:50
#
#         UnitPrice  CustomerID         Country  logic_test
# 0            2.55     17850.0  United Kingdom       False
# 1             NaN     17850.0  United Kingdom       False
# 2            2.75     17850.0  United Kingdom       False
# 3            3.39     17850.0  United Kingdom       False
# ...           ...         ...             ...         ...
# 541906       4.15     12680.0          France        True
# 541907       4.15     12680.0          France        True
# 541908       4.95     12680.0          France        True
# 541909       4.95     12680.0          France        True
#
# [541910 rows x 9 columns]

# %%
retail_data['logic_test'].sum()
# Out:
# 144262
